# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'E:\data analysis projectttttttt\power bi\finalDepi\SalesRecords.csv')
df
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online              C  10/8/2014  535113847
# ...

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online              C 2014-10-08  535113847
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online              C  10/8/2014  535113847
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online              C 2014-10-08  535113847
# ...

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online              C 2014-10-08  535113847
# ...

# %%
df
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online              C 2014-10-08  535113847
# ...

# %%
df.dtypes
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# dtype: object

# %%
df['Order Priority'].replace('L', 'Low', inplace=True)
df
# Out:
# C:\Users\Grand\AppData\Local\Temp\ipykernel_6564\503038376.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Order Priority'].replace('L', 'Low', inplace=True)
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# ...

# %%
df['Order Priority'].replace('H', 'High', inplace=True)
# Out:
# C:\Users\Grand\AppData\Local\Temp\ipykernel_6564\4006863584.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Order Priority'].replace('H', 'High', inplace=True)

# %%
df['Order Priority'].replace('M', 'Median', inplace=True)
# Out:
# C:\Users\Grand\AppData\Local\Temp\ipykernel_6564\3005234424.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Order Priority'].replace('M', 'Median', inplace=True)

# %%
df
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online              C 2014-10-08  535113847
# ...

# %%
df['Order Priority'].replace('C', 'Crtical', inplace=True)
# Out:
# C:\Users\Grand\AppData\Local\Temp\ipykernel_6564\2574556874.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Order Priority'].replace('C', 'Crtical', inplace=True)

# %%
df
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online        Crtical 2014-10-08  535113847
# ...

# %%
df['Unit Price'].round(1)
# Out:
# 0        152.6
# 1        437.2
# 2          9.3
# 3         81.7
# 4        668.3
#          ...
# 99995    205.7
# 99996    421.9
# 99997    109.3
# 99998    437.2
# 99999    437.2
# Name: Unit Price, Length: 100000, dtype: float64

# %%
df
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online        Crtical 2014-10-08  535113847
# ...

# %% [markdown]
# # 1. Total Profit by Item Type (Bar Chart)

# %%
item_profit = df.groupby('Item Type')['Total Profit'].sum().reset_index()

# Sort by Total Profit
item_profit = item_profit.sort_values(by='Total Profit', ascending=False)

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Total Profit', y='Item Type', data=item_profit, palette='coolwarm')
plt.title('Total Profit by Item Type')
plt.xlabel('Total Profit')
plt.ylabel('Item Type')
plt.tight_layout()
# Out:
# C:\Users\Grand\AppData\Local\Temp\ipykernel_6564\1783144693.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Total Profit', y='Item Type', data=item_profit, palette='coolwarm')

# %% [markdown]
# # 2. Units Sold by Sales Channel (Pie Chart)

# %%
sales_channel_units = df.groupby('Sales Channel')['Units Sold'].sum()

# Plotting Pie Chart
plt.figure(figsize=(7, 7))
plt.pie(sales_channel_units, labels=sales_channel_units.index, autopct='%1.1f%%', colors=['#66b3ff','#99ff99'], startangle=90, explode=(0.05, 0))
plt.title('Units Sold by Sales Channel')
plt.tight_layout()

# Show plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Total Revenue'], bins=20, kde=True)
plt.title('Total Revenue Distribution of Properties')
plt.xlabel('Total Revenue')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Total Profit'], bins=20, kde=True)
plt.title('Total Profit Distribution of Properties')
plt.xlabel('Total Profit')
plt.ylabel('Frequency')
plt.show()
